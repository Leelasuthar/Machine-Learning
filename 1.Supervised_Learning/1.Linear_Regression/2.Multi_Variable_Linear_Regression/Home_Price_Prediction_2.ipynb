# %%
import pandas as pd
import  numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv(".\house-prices.csv")
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790       2.0          2       2    No         East
# 1       2  114200  2030       4.0          2       3    No         East
# 2       3  114800  1740       3.0          2       1    No         East
# 3       4   94700  1980       NaN          2       3    No         East
# 4       5  119800  2130       3.0          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900       3.0          3       3   Yes         East
# 124   125  147900  2160       4.0          3       3   Yes         East
# 125   126  113500  2070       2.0          2       2    No        North
# 126   127  149900  2020       3.0          3       1    No         West
# 127   128  124600  2250       3.0          3       4    No        North
#
# [128 rows x 8 columns]

# %%
import math
median_Bedrooms = math.floor(df.Bedrooms.median())
median_Bedrooms
# Out:
# 3

# %%
#Handling/filling the missing values 
df.Bedrooms = df.Bedrooms.fillna(median_Bedrooms)
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790       2.0          2       2    No         East
# 1       2  114200  2030       4.0          2       3    No         East
# 2       3  114800  1740       3.0          2       1    No         East
# 3       4   94700  1980       3.0          2       3    No         East
# 4       5  119800  2130       3.0          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900       3.0          3       3   Yes         East
# 124   125  147900  2160       4.0          3       3   Yes         East
# 125   126  113500  2070       2.0          2       2    No        North
# 126   127  149900  2020       3.0          3       1    No         West
# 127   128  124600  2250       3.0          3       4    No        North
#
# [128 rows x 8 columns]

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['SqFt','Bedrooms','Bathrooms','Offers']],df.Price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([    62.20860623,   9505.16361764,  12192.57772865, -13553.35008498])

# %%
reg.intercept_
# Out:
# -17510.371265907743

# %%
reg.predict([[2500,4.0,4,2]])
# Out:
# C:\Users\DINESH P SUTHAR\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([197695.40953008])

# %%
#y=(m1*x1+m2*x2+m3*x3+b)
62.20860623*2500+9505.16361764*4.0+12192.57772865*4+-13553.35008498*2+-17510.371265907743
# Out:
# 197695.40952429225
